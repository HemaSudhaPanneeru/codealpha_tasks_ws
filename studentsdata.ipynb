# %%
#installing pandas

# %%
# !pip install pandas

# %%
#importing pandas

# %%
import pandas as pd

# %%
#uploading files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d651e81-7b65-47c4-b2e4-271cab17f8ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d651e81-7b65-47c4-b2e4-271cab17f8ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')

# %%
#data

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df.shape
# Out:
# (6607, 20)

# %%
#data cleaning

# %%
df.isnull()
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             False       False                 False                False
# 1             False       False                 False                False
# 2             False       False                 False                False
# 3             False       False                 False                False
# 4             False       False                 False                False
# ...             ...         ...                   ...                  ...
# 6602          False       False                 False                False
# 6603          False       False                 False                False
# 6604          False       False                 False                False
# 6605          False       False                 False                False
# 6606          False       False                 False                False
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.isnull().sum(0)
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
mode_Teacher_Quality=df['Teacher_Quality'].mode()[0]

# %%
df['Teacher_Quality']=df['Teacher_Quality'].fillna(df['Teacher_Quality'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality                0
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
mode_Parental_Education_Level=df['Parental_Education_Level'].mode()[0]

# %%
df['Parental_Education_Level']=df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality                0
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level       0
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
mode_Distance_from_Home=df['Distance_from_Home'].mode()[0]

# %%
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(df['Distance_from_Home'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
#data transformation

# %%
df['Parental_Involvement'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
dict1={'Low':0, 'Medium':1, 'High':2}

# %%
df['Parental_Involvement']=df['Parental_Involvement'].replace(dict1)
# Out:
# /tmp/ipython-input-2366841385.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Parental_Involvement']=df['Parental_Involvement'].replace(dict1)

# %%
df['Access_to_Resources'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
dict2={'Low':0, 'Medium':1, 'High':2}

# %%
df['Access_to_Resources']=df['Access_to_Resources'].replace(dict2)
# Out:
# /tmp/ipython-input-4012527760.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Access_to_Resources']=df['Access_to_Resources'].replace(dict2)

# %%
df['Extracurricular_Activities'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dict3={'No':0, 'Yes':1}

# %%
df['Extracurricular_Activities']=df['Extracurricular_Activities'].replace(dict3)
# Out:
# /tmp/ipython-input-1742406392.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Extracurricular_Activities']=df['Extracurricular_Activities'].replace(dict3)

# %%
df['Motivation_Level'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
dict4={'Low':0, 'Medium':1, 'High':2}

# %%
df['Motivation_Level']=df['Motivation_Level'].replace(dict4)
# Out:
# /tmp/ipython-input-4093418989.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Motivation_Level']=df['Motivation_Level'].replace(dict4)

# %%
df['Internet_Access'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dict5={'No':0, 'Yes':1}

# %%
df['Internet_Access']=df['Internet_Access'].replace(dict5)
# Out:
# /tmp/ipython-input-1435093817.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Internet_Access']=df['Internet_Access'].replace(dict5)

# %%
df['Family_Income'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
dict6={'Low':0, 'Medium':1, 'High':2}

# %%
df['Family_Income']=df['Family_Income'].replace(dict6)
# Out:
# /tmp/ipython-input-3092582801.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Family_Income']=df['Family_Income'].replace(dict6)

# %%
df['Teacher_Quality'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
dict7={'Low':0, 'Medium':1, 'High':2}

# %%
df['Teacher_Quality']=df['Teacher_Quality'].replace(dict7)
# Out:
# /tmp/ipython-input-2468561316.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Teacher_Quality']=df['Teacher_Quality'].replace(dict7)

# %%
df['School_Type'].unique()
# Out:
# array(['Public', 'Private'], dtype=object)

# %%
dict8={'Public':0, 'Private':1}

# %%
df['School_Type']=df['School_Type'].replace(dict8)
# Out:
# /tmp/ipython-input-2406675788.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['School_Type']=df['School_Type'].replace(dict8)

# %%
df['Peer_Influence'].unique()
# Out:
# array(['Positive', 'Negative', 'Neutral'], dtype=object)

# %%
dict9={'Positive':0, 'Negative':1, 'Neutral':2}

# %%
df['Peer_Influence']=df['Peer_Influence'].replace(dict9)
# Out:
# /tmp/ipython-input-4157366374.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Peer_Influence']=df['Peer_Influence'].replace(dict9)

# %%
df['Learning_Disabilities'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dict10={'No':0, 'Yes':1}

# %%
df['Learning_Disabilities']=df['Learning_Disabilities'].replace(dict10)
# Out:
# /tmp/ipython-input-348479828.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Learning_Disabilities']=df['Learning_Disabilities'].replace(dict10)

# %%
df['Parental_Education_Level'].unique()
# Out:
# array(['High School', 'College', 'Postgraduate'], dtype=object)

# %%
dict11={'High School':0, 'College':1, 'Postgraduate':2}

# %%
df['Parental_Education_Level']=df['Parental_Education_Level'].replace(dict11)
# Out:
# /tmp/ipython-input-687407330.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Parental_Education_Level']=df['Parental_Education_Level'].replace(dict11)

# %%
df['Distance_from_Home'].unique()
# Out:
# array(['Near', 'Moderate', 'Far'], dtype=object)

# %%
dict12={'Near':0, 'Moderate':1, 'Far':2}

# %%
df['Distance_from_Home']=df['Distance_from_Home'].replace(dict12)
# Out:
# /tmp/ipython-input-2948253896.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Distance_from_Home']=df['Distance_from_Home'].replace(dict12)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dict13={'Male':0, 'Female':1}

# %%
df['Gender']=df['Gender'].replace(dict13)
# Out:
# /tmp/ipython-input-2683019035.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']=df['Gender'].replace(dict13)

# %%
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
#data visualization

# %%
import matplotlib.pyplot as plt

# %%
df['Parental_Involvement'].value_counts()
# Out:
# Parental_Involvement
# 1    3362
# 2    1908
# 0    1337
# Name: count, dtype: int64

# %%
#Bar Graph

# %%
x=['High','Low','Medium']
y=[3362,1908,1337]
plt.xlabel('Parent involvement')
plt.ylabel('Count')
plt.bar(x,y,color='pink',edgecolor='black')
plt.title('Bar Graph')
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %%
#interpretation
#from this graph we can say that parental involvement is a key factor in student performance factors

# %%
#Histogram

# %%
x=df['Attendance']
y=df['Exam_Score']
plt.xlabel('Attendance')
plt.ylabel('Frequency')
plt.hist(x,bins=5,edgecolor='black',color='skyblue')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
#interpretation
#from this graph we can say that when attendance is increasing students exam score is also increasing in students

# %%
#scatter plot

# %%
x=df['Hours_Studied']
y=df['Exam_Score']
plt.xlabel('Hours_Studied')
plt.ylabel('Exam_Score')
plt.scatter(x,y,color='red')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
#pie chart

# %%
df['Sleep_Hours'].value_counts()
# Out:
# Sleep_Hours
# 7     1741
# 8     1399
# 6     1376
# 9      775
# 5      695
# 10     312
# 4      309
# Name: count, dtype: int64

# %%
df['Sleep_Hours'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %%
#interpretation
#from this piechart we can say that highest sleeping hours of students is 7 hours

# %%
#line chart

# %%
x=df['Attendance']
y=df['Exam_Score']
plt.xlabel('Attendance')
plt.ylabel('Exam_Score')
plt.plot(x,y,color='orange')
plt.title('line chart')
# Out:
# Text(0.5, 1.0, 'line chart')
